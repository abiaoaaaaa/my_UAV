# %%
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import matplotlib.pyplot as plt
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env
import gym
import numpy as np
import time
from stable_baselines3.common.callbacks import EvalCallback
import env_test1
from gymnasium.wrappers import FlattenObservation
env = gym.make('gym_examples/GridWorld-v0')
env = env_test1.DroneEnv()
check_env(env)
env = DummyVecEnv([lambda: env])
# Out:
#   Cell In[1], line 14
#     import gym-examples
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 训练模型

# %%
#vec_env = VecNormalize(env, norm_obs=True, norm_reward=True,clip_obs=1)

model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./tensorboard/",device="cuda")
# Evaluation callback
callbacks = []
eval_callback = EvalCallback(
    env,
    callback_on_new_best=None,
    n_eval_episodes=8,
    best_model_save_path=".",
    log_path=".",
    eval_freq=4000,
)

callbacks.append(eval_callback)
kwargs = {}
kwargs["callback"] = callbacks

log_name = "ppo_run_" + str(time.time())

model.learn(
    total_timesteps=40000,
    tb_log_name=log_name,
    **kwargs
)
# Out:
# Using cuda device
# Logging to ./tensorboard/ppo_run_1713613580.671156_1
# -----------------------------
# | time/              |      |
# |    fps             | 1107 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=4000, episode_reward=-6304.61 +/- 0.00
# Episode length: 501.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 501           |
# |    mean_reward          | -6.3e+03      |
# | time/                   |               |
# |    total_timesteps      | 4000          |
# | train/                  |               |
# |    approx_kl            | 4.6947534e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 1.2e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.92e+05      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -4.32e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.63e+06      |
# -------------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 591  |
# |    iterations      | 2    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 4096 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 620           |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 2.0091858e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -2.26e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.82e+05      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -4.47e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.28e+06      |
# -------------------------------------------
# Eval num_timesteps=8000, episode_reward=-5162.50 +/- 0.00
# Episode length: 501.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 501          |
# |    mean_reward          | -5.16e+03    |
# | time/                   |              |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 0.0014372827 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -2.94e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.89e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00217     |
# |    std                  | 0.999        |
# |    value_loss           | 8.79e+05     |
# ------------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 545  |
# |    iterations      | 4    |
# |    time_elapsed    | 15   |
# |    total_timesteps | 8192 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0005336667 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -3.66e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.21e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000958    |
# |    std                  | 1.01         |
# |    value_loss           | 1.08e+06     |
# ------------------------------------------
# Eval num_timesteps=12000, episode_reward=-33597.33 +/- 0.00
# Episode length: 254.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 254          |
# |    mean_reward          | -3.36e+04    |
# | time/                   |              |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 9.017065e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 2.09e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+06     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -6.43e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 2.18e+06     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 553   |
# |    iterations      | 6     |
# |    time_elapsed    | 22    |
# |    total_timesteps | 12288 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 7             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 2.2671156e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 1.48e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.89e+06      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000324     |
# |    std                  | 1.01          |
# |    value_loss           | 7.82e+06      |
# -------------------------------------------
# Eval num_timesteps=16000, episode_reward=-4620.30 +/- 0.00
# Episode length: 268.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 268          |
# |    mean_reward          | -4.62e+03    |
# | time/                   |              |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0001226213 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 1.62e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+06      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000486    |
# |    std                  | 1.02         |
# |    value_loss           | 1.95e+06     |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 561   |
# |    iterations      | 8     |
# |    time_elapsed    | 29    |
# |    total_timesteps | 16384 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 573           |
# |    iterations           | 9             |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00048626296 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | 1.82e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.37e+05      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00092      |
# |    std                  | 1.04          |
# |    value_loss           | 9.13e+05      |
# -------------------------------------------
# Eval num_timesteps=20000, episode_reward=-1501.25 +/- 0.00
# Episode length: 274.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 274           |
# |    mean_reward          | -1.5e+03      |
# | time/                   |               |
# |    total_timesteps      | 20000         |
# | train/                  |               |
# |    approx_kl            | 0.00011625845 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 6.2e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.81e+05      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000225     |
# |    std                  | 1.04          |
# |    value_loss           | 5.42e+05      |
# -------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 563   |
# |    iterations      | 10    |
# |    time_elapsed    | 36    |
# |    total_timesteps | 20480 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 570           |
# |    iterations           | 11            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00060513744 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -1.35e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.76e+05      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000915     |
# |    std                  | 1.02          |
# |    value_loss           | 7.32e+05      |
# -------------------------------------------
# Eval num_timesteps=24000, episode_reward=-27616.63 +/- 0.00
# Episode length: 260.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 260           |
# |    mean_reward          | -2.76e+04     |
# | time/                   |               |
# |    total_timesteps      | 24000         |
# | train/                  |               |
# |    approx_kl            | 4.3515436e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 3.7e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.97e+06      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000624     |
# |    std                  | 1.03          |
# |    value_loss           | 1.84e+06      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 564   |
# |    iterations      | 12    |
# |    time_elapsed    | 43    |
# |    total_timesteps | 24576 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 569           |
# |    iterations           | 13            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 2.3655622e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 2.44e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.71e+05      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000236     |
# |    std                  | 1.02          |
# |    value_loss           | 1.23e+06      |
# -------------------------------------------
# Eval num_timesteps=28000, episode_reward=-12037.62 +/- 0.00
# Episode length: 276.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 276           |
# |    mean_reward          | -1.2e+04      |
# | time/                   |               |
# |    total_timesteps      | 28000         |
# | train/                  |               |
# |    approx_kl            | 4.9072347e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 3.16e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.84e+05      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000519     |
# |    std                  | 1.03          |
# |    value_loss           | 1.98e+06      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 562   |
# |    iterations      | 14    |
# |    time_elapsed    | 51    |
# |    total_timesteps | 28672 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 15           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0050569796 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 1.38e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.85e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0049      |
# |    std                  | 1.02         |
# |    value_loss           | 9.27e+04     |
# ------------------------------------------
# Eval num_timesteps=32000, episode_reward=-31470.49 +/- 0.00
# Episode length: 256.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 256           |
# |    mean_reward          | -3.15e+04     |
# | time/                   |               |
# |    total_timesteps      | 32000         |
# | train/                  |               |
# |    approx_kl            | 0.00045600135 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 2.5e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.56e+05      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00109      |
# |    std                  | 1.02          |
# |    value_loss           | 5.64e+05      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 564   |
# |    iterations      | 16    |
# |    time_elapsed    | 58    |
# |    total_timesteps | 32768 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 570           |
# |    iterations           | 17            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00010339398 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 1.43e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.15e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000291     |
# |    std                  | 1.01          |
# |    value_loss           | 1.94e+06      |
# -------------------------------------------
# Eval num_timesteps=36000, episode_reward=-28999.99 +/- 0.00
# Episode length: 263.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 263          |
# |    mean_reward          | -2.9e+04     |
# | time/                   |              |
# |    total_timesteps      | 36000        |
# | train/                  |              |
# |    approx_kl            | 8.319807e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 1.37e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52e+06     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000553    |
# |    std                  | 1.01         |
# |    value_loss           | 3.99e+06     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 565   |
# |    iterations      | 18    |
# |    time_elapsed    | 65    |
# |    total_timesteps | 36864 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 19           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 9.535288e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 1.13e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.44e+06     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000296    |
# |    std                  | 1.01         |
# |    value_loss           | 7.15e+06     |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=-8658.81 +/- 0.00
# Episode length: 274.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 274          |
# |    mean_reward          | -8.66e+03    |
# | time/                   |              |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0004910196 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 2.03e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.66e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 1.01         |
# |    value_loss           | 1.32e+06     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 563   |
# |    iterations      | 20    |
# |    time_elapsed    | 72    |
# |    total_timesteps | 40960 |
# ------------------------------

# %% [markdown]
# ### 绘图检验

# %%
import matplotlib.pyplot as plt

# 创建一个包含一个子图的窗口
fig, ax = plt.subplots(figsize=(8, 6))

env = env_test1.DroneEnv()

# 重置环境
state, info = env.reset()
trajectory_x = [env.xy_p[0]]  # 存储无人机路径的x坐标
trajectory_y = [env.xy_p[1]]  # 存储无人机路径的y坐标
trajectory_ex = [env.xy_e[0]]  # 存储无人机路径的x坐标
trajectory_ey = [env.xy_e[1]]  # 存储无人机路径的y坐标

# 在子图中绘制环境和障碍物
ax.scatter(env.xy_e[0], env.xy_e[1], marker='x', color='green', label='Goal')
for k in env.obstacles:
    obstacle_circle = plt.Circle(k, env.r_obstacles, color='lightblue', fill=True)
    ax.add_patch(obstacle_circle)
ax.set_xlim(env.space1.low[0], env.space1.high[0])
ax.set_ylim(env.space1.low[1], env.space1.high[1])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.legend()
ax.set_title('Drone Path')

# 通过预训练模型控制无人机执行任务并绘制路径
#model = PPO.load("best_model") 
done = False
total_reward = 0
count = 0
while not done:
    count += 1
    action, _states = model.predict(state, deterministic=True)
    next_state, reward, done, t, info = env.step(action)
    #if reward < -10:
        #print(state, action, reward)
    if count > 500:
        done = True
    total_reward += reward
    state = next_state
    trajectory_x.append(env.xy_p[0])  # 更新无人机路径的x坐标
    trajectory_y.append(env.xy_p[1])  # 更新无人机路径的y坐标
    trajectory_ex.append(env.xy_e[0])  # 更新无人机路径的x坐标
    trajectory_ey.append(env.xy_e[1])  # 更新无人机路径的y坐标

# 绘制无人机路径
ax.plot(trajectory_x, trajectory_y, color='red', linewidth=0.5)
ax.plot(trajectory_ex, trajectory_ey, color='red', linewidth=0.5)

# 打印每个episode的总奖励
print('Total reward:', total_reward)

# 显示子图窗口
plt.tight_layout()
plt.show()
# Out:
# Total reward: -1422.4533890173227

# %%
import matplotlib.pyplot as plt

# 创建一个包含一个子图的窗口
fig, ax = plt.subplots(figsize=(8, 6))

env = env_test1.DroneEnv()

# 重置环境
state, info = env.reset()
trajectory_x = [env.xy_p[0]]  # 存储无人机路径的x坐标
trajectory_y = [env.xy_p[1]]  # 存储无人机路径的y坐标
trajectory_ex = [env.xy_e[0]]  # 存储无人机路径的x坐标
trajectory_ey = [env.xy_e[1]]  # 存储无人机路径的y坐标

# 在子图中绘制环境和障碍物
ax.scatter(env.xy_e[0], env.xy_e[1], marker='x', color='green', label='Goal')
for k in env.obstacles:
    obstacle_circle = plt.Circle(k, env.r_obstacles, color='lightblue', fill=True)
    ax.add_patch(obstacle_circle)
ax.set_xlim(env.space1.low[0], env.space1.high[0])
ax.set_ylim(env.space1.low[1], env.space1.high[1])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.legend()
ax.set_title('Drone Path')

# 通过预训练模型控制无人机执行任务并绘制路径
model = PPO.load("best_model") 
done = False
total_reward = 0
count = 0
while not done:
    count += 1
    action, _states = model.predict(state, deterministic=True)
    next_state, reward, done, t, info = env.step(action)
    #if reward < -10:
        #print(state, action, reward)
    if count > 500:
        done = True
    total_reward += reward
    state = next_state
    trajectory_x.append(env.xy_p[0])  # 更新无人机路径的x坐标
    trajectory_y.append(env.xy_p[1])  # 更新无人机路径的y坐标
    trajectory_ex.append(env.xy_e[0])  # 更新无人机路径的x坐标
    trajectory_ey.append(env.xy_e[1])  # 更新无人机路径的y坐标

# 绘制无人机路径
ax.plot(trajectory_x, trajectory_y, color='red', linewidth=0.5)
ax.plot(trajectory_ex, trajectory_ey, color='red', linewidth=0.5)

# 打印每个episode的总奖励
print('Total reward:', total_reward)

# 显示子图窗口
plt.tight_layout()
plt.show()
# Out:
# Total reward: -1390.487300798675

# %% [markdown]
# ### 逐渐学习ing

# %%
#vec_env = VecNormalize(env, norm_obs=True, norm_reward=True,clip_obs=1)
# Evaluation callback
callbacks = []
eval_callback = EvalCallback(
    env,
    callback_on_new_best=None,
    n_eval_episodes=8,
    best_model_save_path=".",
    log_path=".",
    eval_freq=4000,
)
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./tensorboard/",device="cuda")
callbacks.append(eval_callback)
kwargs = {}
kwargs["callback"] = callbacks

log_name = "ppo_run_" + str(time.time())

model.set_parameters("last_model")
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Before training: mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
model.learn(
    total_timesteps=4000,
    tb_log_name=log_name,
    **kwargs
)
# Out:
# Using cuda device
# Logging to ./tensorboard/ppo_run_1713612304.9204388_1
# -----------------------------
# | time/              |      |
# |    fps             | 1088 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=4000, episode_reward=-31822.82 +/- 0.00
# Episode length: 257.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 257           |
# |    mean_reward          | -3.18e+04     |
# | time/                   |               |
# |    total_timesteps      | 4000          |
# | train/                  |               |
# |    approx_kl            | 0.00050762075 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -6.54e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.08e+05      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000794     |
# |    std                  | 1             |
# |    value_loss           | 9.78e+05      |
# -------------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 677  |
# |    iterations      | 2    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 4096 |
# -----------------------------

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./tensorboard/",device="cuda")
model.set_parameters("last_model")
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Before training: mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
