# %%
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import matplotlib.pyplot as plt
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env
import gym
import numpy as np
import time
from stable_baselines3.common.callbacks import EvalCallback
import env_test1
env = env_test1.DroneEnv()
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
import time
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback


# 加载预训练的模型
model = PPO.load("best_model")

# Evaluation callback
eval_callback = EvalCallback(
    env,
    eval_freq=500,
    n_eval_episodes=4,
    best_model_save_path=".",
    log_path=".",
)

# 继续训练加载的模型
model.learn(
    total_timesteps=200000,
    callback=eval_callback,
    tb_log_name="ppo_run_" + str(time.time()),
)

# %% [markdown]
# ### 训练模型

# %%
#vec_env = VecNormalize(env, norm_obs=True, norm_reward=True,clip_obs=1)

model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./tensorboard/",device="cuda")
# Evaluation callback
callbacks = []
eval_callback = EvalCallback(
    env,
    callback_on_new_best=None,
    n_eval_episodes=8,
    best_model_save_path=".",
    log_path=".",
    eval_freq=4000,
)

callbacks.append(eval_callback)
kwargs = {}
kwargs["callback"] = callbacks

log_name = "ppo_run_" + str(time.time())

model.learn(
    total_timesteps=500000,
    tb_log_name=log_name,
    **kwargs
)
# Out:
# Using cuda device
# Logging to ./tensorboard/ppo_run_1713415221.1753156_1
# -----------------------------
# | time/              |      |
# |    fps             | 432  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# C:\ProgramData\anaconda3\envs\UAV\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=4000, episode_reward=-35116.51 +/- 26411.73
# Episode length: 501.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 501          |
# |    mean_reward          | -3.51e+04    |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0008108872 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 1.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.53e+05     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00117     |
# |    std                  | 1.01         |
# |    value_loss           | 1.05e+06     |
# ------------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 414  |
# |    iterations      | 2    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 4096 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 3             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00086200674 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -4.9e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.96e+05      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00149      |
# |    std                  | 0.999         |
# |    value_loss           | 8.54e+05      |
# -------------------------------------------
# Eval num_timesteps=8000, episode_reward=-23519.19 +/- 25774.81
# Episode length: 339.88 +/- 45.08
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 340           |
# |    mean_reward          | -2.35e+04     |
# | time/                   |               |
# |    total_timesteps      | 8000          |
# | train/                  |               |
# |    approx_kl            | 1.8204591e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -9.54e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.87e+06      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000322     |
# |    std                  | 0.997         |
# |    value_loss           | 7.89e+06      |
# -------------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 489  |
# |    iterations      | 4    |
# |    time_elapsed    | 16   |
# |    total_timesteps | 8192 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 525          |
# |    iterations           | 5            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0011011921 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -5.48e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000947    |
# |    std                  | 1            |
# |    value_loss           | 3.29e+05     |
# ------------------------------------------
# Eval num_timesteps=12000, episode_reward=-29340.92 +/- 20173.87
# Episode length: 327.50 +/- 36.98
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 328          |
# |    mean_reward          | -2.93e+04    |
# | time/                   |              |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 3.061458e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 2.78e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+06     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000108    |
# |    std                  | 1            |
# |    value_loss           | 2.88e+06     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 519   |
# |    iterations      | 6     |
# |    time_elapsed    | 23    |
# |    total_timesteps | 12288 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0007919838 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -2.62e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000864    |
# |    std                  | 0.991        |
# |    value_loss           | 3.28e+05     |
# ------------------------------------------
# Eval num_timesteps=16000, episode_reward=-25005.13 +/- 24042.81
# Episode length: 282.75 +/- 47.17
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 283         |
# |    mean_reward          | -2.5e+04    |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.013464326 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -2.72e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.975       |
# |    value_loss           | 3.82e+04    |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 540   |
# |    iterations      | 8     |
# |    time_elapsed    | 30    |
# |    total_timesteps | 16384 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.000223765 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 7.03e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29e+06    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000661   |
# |    std                  | 0.992       |
# |    value_loss           | 4.39e+06    |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=-28492.38 +/- 27821.41
# Episode length: 320.50 +/- 42.16
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 320           |
# |    mean_reward          | -2.85e+04     |
# | time/                   |               |
# |    total_timesteps      | 20000         |
# | train/                  |               |
# |    approx_kl            | 1.6690115e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 7.33e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.46e+06      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -8.53e-05     |
# |    std                  | 0.995         |
# |    value_loss           | 3.39e+06      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 550   |
# |    iterations      | 10    |
# |    time_elapsed    | 37    |
# |    total_timesteps | 20480 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 11          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015590187 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -4.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.94        |
# |    value_loss           | 3.13e+04    |
# -----------------------------------------
# Eval num_timesteps=24000, episode_reward=-29430.44 +/- 18934.15
# Episode length: 324.25 +/- 23.86
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 324           |
# |    mean_reward          | -2.94e+04     |
# | time/                   |               |
# |    total_timesteps      | 24000         |
# | train/                  |               |
# |    approx_kl            | 2.1431391e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 3.04e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.81e+06      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000103     |
# |    std                  | 0.938         |
# |    value_loss           | 1.27e+07      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 556   |
# |    iterations      | 12    |
# |    time_elapsed    | 44    |
# |    total_timesteps | 24576 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 565           |
# |    iterations           | 13            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00021628529 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 4.05e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.3e+05       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000238     |
# |    std                  | 0.936         |
# |    value_loss           | 1.58e+06      |
# -------------------------------------------
# Eval num_timesteps=28000, episode_reward=-12604.40 +/- 13281.52
# Episode length: 324.00 +/- 43.47
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 324           |
# |    mean_reward          | -1.26e+04     |
# | time/                   |               |
# |    total_timesteps      | 28000         |
# | train/                  |               |
# |    approx_kl            | 0.00036147464 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 2.03e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.44e+06      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000942     |
# |    std                  | 0.935         |
# |    value_loss           | 1.05e+07      |
# -------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 560   |
# |    iterations      | 14    |
# |    time_elapsed    | 51    |
# |    total_timesteps | 28672 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 570           |
# |    iterations           | 15            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 6.3123036e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 2.21e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.09e+06      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000307     |
# |    std                  | 0.932         |
# |    value_loss           | 1.33e+07      |
# -------------------------------------------
# Eval num_timesteps=32000, episode_reward=-30346.57 +/- 15162.50
# Episode length: 318.50 +/- 28.19
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 318           |
# |    mean_reward          | -3.03e+04     |
# | time/                   |               |
# |    total_timesteps      | 32000         |
# | train/                  |               |
# |    approx_kl            | 4.8323942e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 1.85e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.06e+06      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000282     |
# |    std                  | 0.936         |
# |    value_loss           | 1.84e+07      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 565   |
# |    iterations      | 16    |
# |    time_elapsed    | 57    |
# |    total_timesteps | 32768 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 574           |
# |    iterations           | 17            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 6.0706487e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 2.21e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.07e+06      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000284     |
# |    std                  | 0.931         |
# |    value_loss           | 9.67e+06      |
# -------------------------------------------
# Eval num_timesteps=36000, episode_reward=-12273.42 +/- 18874.60
# Episode length: 314.88 +/- 26.85
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 315          |
# |    mean_reward          | -1.23e+04    |
# | time/                   |              |
# |    total_timesteps      | 36000        |
# | train/                  |              |
# |    approx_kl            | 7.542607e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 1.61e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.43e+06     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -3.07e-05    |
# |    std                  | 0.933        |
# |    value_loss           | 1.36e+07     |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 570   |
# |    iterations      | 18    |
# |    time_elapsed    | 64    |
# |    total_timesteps | 36864 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 577           |
# |    iterations           | 19            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 6.8037625e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 1.55e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.36e+06      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000341     |
# |    std                  | 0.929         |
# |    value_loss           | 1.44e+07      |
# -------------------------------------------
# Eval num_timesteps=40000, episode_reward=-36108.55 +/- 23892.41
# Episode length: 335.25 +/- 48.62
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 335          |
# |    mean_reward          | -3.61e+04    |
# | time/                   |              |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 6.906432e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 1.31e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.49e+06     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0004      |
# |    std                  | 0.922        |
# |    value_loss           | 1.17e+07     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 572   |
# |    iterations      | 20    |
# |    time_elapsed    | 71    |
# |    total_timesteps | 40960 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 21           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 7.424463e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 1.73e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.68e+06     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000303    |
# |    std                  | 0.929        |
# |    value_loss           | 8.26e+06     |
# ------------------------------------------
# Eval num_timesteps=44000, episode_reward=-33915.78 +/- 17053.07
# Episode length: 282.38 +/- 49.90
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 282           |
# |    mean_reward          | -3.39e+04     |
# | time/                   |               |
# |    total_timesteps      | 44000         |
# | train/                  |               |
# |    approx_kl            | 0.00058213284 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 2.15e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.18e+04      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000447     |
# |    std                  | 0.91          |
# |    value_loss           | 6.56e+05      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 577   |
# |    iterations      | 22    |
# |    time_elapsed    | 78    |
# |    total_timesteps | 45056 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 23           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 8.694132e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 7.15e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.03e+06     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000349    |
# |    std                  | 0.909        |
# |    value_loss           | 1.5e+07      |
# ------------------------------------------
# Eval num_timesteps=48000, episode_reward=-15914.81 +/- 19620.46
# Episode length: 329.12 +/- 12.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 329         |
# |    mean_reward          | -1.59e+04   |
# | time/                   |             |
# |    total_timesteps      | 48000       |
# | train/                  |             |
# |    approx_kl            | 3.60602e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.05e+06    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000243   |
# |    std                  | 0.908       |
# |    value_loss           | 1.09e+07    |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 578   |
# |    iterations      | 24    |
# |    time_elapsed    | 84    |
# |    total_timesteps | 49152 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 25           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 6.685089e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 7.15e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.1e+06      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000375    |
# |    std                  | 0.91         |
# |    value_loss           | 1.2e+07      |
# ------------------------------------------
# Eval num_timesteps=52000, episode_reward=-13471.07 +/- 13873.37
# Episode length: 310.50 +/- 41.55
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 310          |
# |    mean_reward          | -1.35e+04    |
# | time/                   |              |
# |    total_timesteps      | 52000        |
# | train/                  |              |
# |    approx_kl            | 5.121721e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.92e+06     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000176    |
# |    std                  | 0.91         |
# |    value_loss           | 6.32e+06     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 581   |
# |    iterations      | 26    |
# |    time_elapsed    | 91    |
# |    total_timesteps | 53248 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 27            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.5006692e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 4.77e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.06e+06      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000241     |
# |    std                  | 0.911         |
# |    value_loss           | 1.4e+07       |
# -------------------------------------------
# Eval num_timesteps=56000, episode_reward=-27454.26 +/- 20585.71
# Episode length: 296.38 +/- 45.98
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 296           |
# |    mean_reward          | -2.75e+04     |
# | time/                   |               |
# |    total_timesteps      | 56000         |
# | train/                  |               |
# |    approx_kl            | 0.00013818024 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 5.36e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.74e+06      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000411     |
# |    std                  | 0.919         |
# |    value_loss           | 8.96e+06      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 584   |
# |    iterations      | 28    |
# |    time_elapsed    | 98    |
# |    total_timesteps | 57344 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 29           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 8.724915e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+06     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00025     |
# |    std                  | 0.924        |
# |    value_loss           | 1.08e+07     |
# ------------------------------------------
# Eval num_timesteps=60000, episode_reward=-16820.13 +/- 18891.94
# Episode length: 310.50 +/- 60.53
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 310           |
# |    mean_reward          | -1.68e+04     |
# | time/                   |               |
# |    total_timesteps      | 60000         |
# | train/                  |               |
# |    approx_kl            | 8.6415734e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.03e+07      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00036      |
# |    std                  | 0.92          |
# |    value_loss           | 1.62e+07      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 585   |
# |    iterations      | 30    |
# |    time_elapsed    | 104   |
# |    total_timesteps | 61440 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 31           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 6.701544e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.56e+06     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000459    |
# |    std                  | 0.913        |
# |    value_loss           | 9.82e+06     |
# ------------------------------------------
# Eval num_timesteps=64000, episode_reward=-27958.17 +/- 18872.20
# Episode length: 313.62 +/- 32.63
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 314           |
# |    mean_reward          | -2.8e+04      |
# | time/                   |               |
# |    total_timesteps      | 64000         |
# | train/                  |               |
# |    approx_kl            | 0.00039832422 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.01e+06      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000733     |
# |    std                  | 0.905         |
# |    value_loss           | 8.78e+06      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 586   |
# |    iterations      | 32    |
# |    time_elapsed    | 111   |
# |    total_timesteps | 65536 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 33           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 4.737533e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03e+06     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000381    |
# |    std                  | 0.901        |
# |    value_loss           | 9.74e+06     |
# ------------------------------------------
# Eval num_timesteps=68000, episode_reward=-20439.54 +/- 15913.25
# Episode length: 311.25 +/- 38.79
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 311          |
# |    mean_reward          | -2.04e+04    |
# | time/                   |              |
# |    total_timesteps      | 68000        |
# | train/                  |              |
# |    approx_kl            | 0.0035399245 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.58e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.911        |
# |    value_loss           | 7.04e+05     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 586   |
# |    iterations      | 34    |
# |    time_elapsed    | 118   |
# |    total_timesteps | 69632 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 590           |
# |    iterations           | 35            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 9.9196564e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.95e+06      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000393     |
# |    std                  | 0.915         |
# |    value_loss           | 4.81e+06      |
# -------------------------------------------
# Eval num_timesteps=72000, episode_reward=-28595.49 +/- 13639.46
# Episode length: 324.38 +/- 51.79
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 324          |
# |    mean_reward          | -2.86e+04    |
# | time/                   |              |
# |    total_timesteps      | 72000        |
# | train/                  |              |
# |    approx_kl            | 5.907673e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+07     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000126    |
# |    std                  | 0.917        |
# |    value_loss           | 1.88e+07     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 587   |
# |    iterations      | 36    |
# |    time_elapsed    | 125   |
# |    total_timesteps | 73728 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 590           |
# |    iterations           | 37            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 3.7558348e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.21e+07      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000152     |
# |    std                  | 0.916         |
# |    value_loss           | 2.14e+07      |
# -------------------------------------------
# Eval num_timesteps=76000, episode_reward=-19665.03 +/- 27105.66
# Episode length: 302.88 +/- 31.78
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 303           |
# |    mean_reward          | -1.97e+04     |
# | time/                   |               |
# |    total_timesteps      | 76000         |
# | train/                  |               |
# |    approx_kl            | 1.1379307e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.15e+07      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -9.97e-05     |
# |    std                  | 0.914         |
# |    value_loss           | 2.28e+07      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 587   |
# |    iterations      | 38    |
# |    time_elapsed    | 132   |
# |    total_timesteps | 77824 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 590           |
# |    iterations           | 39            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 2.5605812e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.72e+06      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.00015      |
# |    std                  | 0.914         |
# |    value_loss           | 1.31e+07      |
# -------------------------------------------
# Eval num_timesteps=80000, episode_reward=-29248.86 +/- 14479.79
# Episode length: 276.25 +/- 38.51
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 276          |
# |    mean_reward          | -2.92e+04    |
# | time/                   |              |
# |    total_timesteps      | 80000        |
# | train/                  |              |
# |    approx_kl            | 0.0001070821 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.89e+06     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000312    |
# |    std                  | 0.916        |
# |    value_loss           | 1.59e+07     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 589   |
# |    iterations      | 40    |
# |    time_elapsed    | 139   |
# |    total_timesteps | 81920 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 592           |
# |    iterations           | 41            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 2.9602088e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.01e+06      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000236     |
# |    std                  | 0.921         |
# |    value_loss           | 2.24e+07      |
# -------------------------------------------
# Eval num_timesteps=84000, episode_reward=-13134.99 +/- 14348.98
# Episode length: 339.25 +/- 35.93
# --------------------------------------------
# | eval/                   |                |
# |    mean_ep_length       | 339            |
# |    mean_reward          | -1.31e+04      |
# | time/                   |                |
# |    total_timesteps      | 84000          |
# | train/                  |                |
# |    approx_kl            | 0.000108392036 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.34          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.23e+06       |
# |    n_updates            | 410            |
# |    policy_gradient_loss | -0.000338      |
# |    std                  | 0.924          |
# |    value_loss           | 5.86e+06       |
# --------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 589   |
# |    iterations      | 42    |
# |    time_elapsed    | 145   |
# |    total_timesteps | 86016 |
# ------------------------------
# Eval num_timesteps=88000, episode_reward=-33426.17 +/- 29628.78
# Episode length: 328.25 +/- 53.65
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 328          |
# |    mean_reward          | -3.34e+04    |
# | time/                   |              |
# |    total_timesteps      | 88000        |
# | train/                  |              |
# |    approx_kl            | 0.0002083607 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.08e+06     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000453    |
# |    std                  | 0.936        |
# |    value_loss           | 7.8e+06      |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 587   |
# |    iterations      | 43    |
# |    time_elapsed    | 149   |
# |    total_timesteps | 88064 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 590           |
# |    iterations           | 44            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 3.9345323e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.49e+07      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00023      |
# |    std                  | 0.931         |
# |    value_loss           | 2.36e+07      |
# -------------------------------------------
# Eval num_timesteps=92000, episode_reward=-12419.98 +/- 12655.01
# Episode length: 313.38 +/- 49.72
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 313           |
# |    mean_reward          | -1.24e+04     |
# | time/                   |               |
# |    total_timesteps      | 92000         |
# | train/                  |               |
# |    approx_kl            | 2.7959468e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.1e+07       |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00018      |
# |    std                  | 0.935         |
# |    value_loss           | 1.71e+07      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 587   |
# |    iterations      | 45    |
# |    time_elapsed    | 156   |
# |    total_timesteps | 92160 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 590           |
# |    iterations           | 46            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00038905005 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.39e+06      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000325     |
# |    std                  | 0.939         |
# |    value_loss           | 7.84e+06      |
# -------------------------------------------
# Eval num_timesteps=96000, episode_reward=-16030.60 +/- 14441.05
# Episode length: 301.00 +/- 36.22
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 301           |
# |    mean_reward          | -1.6e+04      |
# | time/                   |               |
# |    total_timesteps      | 96000         |
# | train/                  |               |
# |    approx_kl            | 4.0519226e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.06e+06      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000619     |
# |    std                  | 0.935         |
# |    value_loss           | 7.18e+06      |
# -------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 588   |
# |    iterations      | 47    |
# |    time_elapsed    | 163   |
# |    total_timesteps | 96256 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 590           |
# |    iterations           | 48            |
# |    time_elapsed         | 166           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.4237477e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.58e+07      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.0001       |
# |    std                  | 0.937         |
# |    value_loss           | 2.88e+07      |
# -------------------------------------------
# Eval num_timesteps=100000, episode_reward=-21553.81 +/- 16132.72
# Episode length: 331.88 +/- 44.45
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 332           |
# |    mean_reward          | -2.16e+04     |
# | time/                   |               |
# |    total_timesteps      | 100000        |
# | train/                  |               |
# |    approx_kl            | 0.00012656281 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.11e+06      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000257     |
# |    std                  | 0.943         |
# |    value_loss           | 9.21e+06      |
# ...
# |    total_timesteps | 468992 |
# -------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 230           |
# |    time_elapsed         | 803           |
# |    total_timesteps      | 471040        |
# | train/                  |               |
# |    approx_kl            | 4.2069005e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.0837        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.82e+06      |
# |    n_updates            | 2290          |
# |    policy_gradient_loss | -0.0001       |
# |    std                  | 0.955         |
# |    value_loss           | 7.12e+06      |
# -------------------------------------------
# Eval num_timesteps=472000, episode_reward=-21527.01 +/- 24723.33
# Episode length: 340.75 +/- 43.62
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 341           |
# |    mean_reward          | -2.15e+04     |
# | time/                   |               |
# |    total_timesteps      | 472000        |
# | train/                  |               |
# |    approx_kl            | 1.3888872e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.0932        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.64e+06      |
# |    n_updates            | 2300          |
# |    policy_gradient_loss | -0.000109     |
# |    std                  | 0.952         |
# |    value_loss           | 8.19e+06      |
# -------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 231    |
# |    time_elapsed    | 807    |
# |    total_timesteps | 473088 |
# -------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 232           |
# |    time_elapsed         | 810           |
# |    total_timesteps      | 475136        |
# | train/                  |               |
# |    approx_kl            | 2.1979416e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.137         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.21e+05      |
# |    n_updates            | 2310          |
# |    policy_gradient_loss | -1.7e-05      |
# |    std                  | 0.954         |
# |    value_loss           | 2.23e+06      |
# -------------------------------------------
# Eval num_timesteps=476000, episode_reward=-13035.20 +/- 11806.67
# Episode length: 382.38 +/- 37.10
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 382           |
# |    mean_reward          | -1.3e+04      |
# | time/                   |               |
# |    total_timesteps      | 476000        |
# | train/                  |               |
# |    approx_kl            | 0.00030578746 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.156         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.87e+05      |
# |    n_updates            | 2320          |
# |    policy_gradient_loss | 1.34e-05      |
# |    std                  | 0.952         |
# |    value_loss           | 8.88e+05      |
# -------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 233    |
# |    time_elapsed    | 814    |
# |    total_timesteps | 477184 |
# -------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 234           |
# |    time_elapsed         | 817           |
# |    total_timesteps      | 479232        |
# | train/                  |               |
# |    approx_kl            | 5.7066558e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.281         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.19e+04      |
# |    n_updates            | 2330          |
# |    policy_gradient_loss | -0.000211     |
# |    std                  | 0.946         |
# |    value_loss           | 2.5e+05       |
# -------------------------------------------
# Eval num_timesteps=480000, episode_reward=-17853.55 +/- 17726.80
# Episode length: 347.88 +/- 64.27
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 348           |
# |    mean_reward          | -1.79e+04     |
# | time/                   |               |
# |    total_timesteps      | 480000        |
# | train/                  |               |
# |    approx_kl            | 2.7507078e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.154         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.69e+05      |
# |    n_updates            | 2340          |
# |    policy_gradient_loss | 1.63e-05      |
# |    std                  | 0.944         |
# |    value_loss           | 1.33e+06      |
# -------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 235    |
# |    time_elapsed    | 821    |
# |    total_timesteps | 481280 |
# -------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 236           |
# |    time_elapsed         | 824           |
# |    total_timesteps      | 483328        |
# | train/                  |               |
# |    approx_kl            | 7.9248246e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.13          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.21e+05      |
# |    n_updates            | 2350          |
# |    policy_gradient_loss | -0.000361     |
# |    std                  | 0.944         |
# |    value_loss           | 1.39e+06      |
# -------------------------------------------
# Eval num_timesteps=484000, episode_reward=-13773.14 +/- 16611.12
# Episode length: 394.75 +/- 56.04
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 395          |
# |    mean_reward          | -1.38e+04    |
# | time/                   |              |
# |    total_timesteps      | 484000       |
# | train/                  |              |
# |    approx_kl            | 4.182424e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45e+06     |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -1.05e-05    |
# |    std                  | 0.945        |
# |    value_loss           | 1.53e+06     |
# ------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 237    |
# |    time_elapsed    | 828    |
# |    total_timesteps | 485376 |
# -------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 238           |
# |    time_elapsed         | 831           |
# |    total_timesteps      | 487424        |
# | train/                  |               |
# |    approx_kl            | 6.7321525e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.11          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.11e+06      |
# |    n_updates            | 2370          |
# |    policy_gradient_loss | -0.000164     |
# |    std                  | 0.95          |
# |    value_loss           | 3.85e+06      |
# -------------------------------------------
# Eval num_timesteps=488000, episode_reward=-7557.79 +/- 6470.20
# Episode length: 368.50 +/- 47.05
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 368           |
# |    mean_reward          | -7.56e+03     |
# | time/                   |               |
# |    total_timesteps      | 488000        |
# | train/                  |               |
# |    approx_kl            | 0.00011454671 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.133         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+06      |
# |    n_updates            | 2380          |
# |    policy_gradient_loss | -0.000314     |
# |    std                  | 0.95          |
# |    value_loss           | 1.73e+06      |
# -------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 239    |
# |    time_elapsed    | 835    |
# |    total_timesteps | 489472 |
# -------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 240          |
# |    time_elapsed         | 838          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 2.488587e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.36e+05     |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | 7.19e-06     |
# |    std                  | 0.948        |
# |    value_loss           | 6.47e+05     |
# ------------------------------------------
# Eval num_timesteps=492000, episode_reward=-8245.79 +/- 9897.13
# Episode length: 365.12 +/- 48.02
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 365           |
# |    mean_reward          | -8.25e+03     |
# | time/                   |               |
# |    total_timesteps      | 492000        |
# | train/                  |               |
# |    approx_kl            | 2.4190871e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.0968        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.76e+06      |
# |    n_updates            | 2400          |
# |    policy_gradient_loss | -0.000316     |
# |    std                  | 0.947         |
# |    value_loss           | 7.55e+06      |
# -------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 241    |
# |    time_elapsed    | 842    |
# |    total_timesteps | 493568 |
# -------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 585            |
# |    iterations           | 242            |
# |    time_elapsed         | 845            |
# |    total_timesteps      | 495616         |
# | train/                  |                |
# |    approx_kl            | 0.000100181176 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.36          |
# |    explained_variance   | 0.0902         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 8.96e+06       |
# |    n_updates            | 2410           |
# |    policy_gradient_loss | -0.000229      |
# |    std                  | 0.946          |
# |    value_loss           | 7.7e+06        |
# --------------------------------------------
# Eval num_timesteps=496000, episode_reward=-11222.38 +/- 13519.96
# Episode length: 321.25 +/- 55.72
# --------------------------------------------
# | eval/                   |                |
# |    mean_ep_length       | 321            |
# |    mean_reward          | -1.12e+04      |
# | time/                   |                |
# |    total_timesteps      | 496000         |
# | train/                  |                |
# |    approx_kl            | 0.000113854214 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.36          |
# |    explained_variance   | 0.131          |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.5e+05        |
# |    n_updates            | 2420           |
# |    policy_gradient_loss | -5.45e-05      |
# |    std                  | 0.943          |
# |    value_loss           | 1.26e+06       |
# --------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 243    |
# |    time_elapsed    | 849    |
# |    total_timesteps | 497664 |
# -------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 244          |
# |    time_elapsed         | 852          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0011331615 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.303        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53e+05     |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.000463    |
# |    std                  | 0.942        |
# |    value_loss           | 2.03e+05     |
# ------------------------------------------
# Eval num_timesteps=500000, episode_reward=-22221.27 +/- 25416.44
# Episode length: 363.75 +/- 50.68
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 364           |
# |    mean_reward          | -2.22e+04     |
# | time/                   |               |
# |    total_timesteps      | 500000        |
# | train/                  |               |
# |    approx_kl            | 2.7773785e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.369         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.9e+04       |
# |    n_updates            | 2440          |
# |    policy_gradient_loss | 2.33e-05      |
# |    std                  | 0.939         |
# |    value_loss           | 1.43e+05      |
# -------------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 585    |
# |    iterations      | 245    |
# |    time_elapsed    | 856    |
# |    total_timesteps | 501760 |
# -------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Before training: mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# 开始训练
#model.learn(total_timesteps=100000,tb_log_name=log_name,
    #**kwargs)
# 评估训练后的 policy
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"After training: mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Before training: mean_reward:-10237.85 +/- 11383.68
# After training: mean_reward:-14469.82 +/- 16854.59

# %% [markdown]
# ### 绘图检验

# %%
import matplotlib.pyplot as plt

# 创建一个包含10个子图的窗口
fig, axs = plt.subplots(2, 5, figsize=(20, 8))
axs = axs.ravel()  # 将二维数组展平，方便通过索引访问每个子图

env = env_test1.DroneEnv()
for i in range(10):
    # 重置环境
    state, info = env.reset()
    trajectory_x = [env.xy_p[0]]  # 存储无人机路径的x坐标
    trajectory_y = [env.xy_p[1]]  # 存储无人机路径的y坐标
    trajectory_ex = [env.xy_e[0]]  # 存储无人机路径的x坐标
    trajectory_ey = [env.xy_e[1]]  # 存储无人机路径的y坐标
    
    # 在第i个子图中绘制环境和障碍物
    axs[i].scatter(env.xy_e[0], env.xy_e[1], marker='x', color='green', label='Goal')
    for k in env.obstacles:
        obstacle_circle = plt.Circle(k, env.r_obstacles, color='lightblue', fill=True)
        axs[i].add_patch(obstacle_circle)
    axs[i].set_xlim(env.space1.low[0], env.space1.high[0])
    axs[i].set_ylim(env.space1.low[1], env.space1.high[1])
    axs[i].set_xlabel('X')
    axs[i].set_ylabel('Y')
    axs[i].legend()
    axs[i].set_title(f'Episode {i+1}')

    # 通过预训练模型控制无人机执行任务并绘制路径
    #model = PPO.load("best_model") 
    done = False
    total_reward = 0
    count = 0
    while not done:
        count += 1
        action, _states = model.predict(state, deterministic=True)
        next_state, reward, done, t, info = env.step(action)
        #if reward < -10:
            #print(state, action, reward)
        if count > 500:
            done = True
        total_reward += reward
        state = next_state
        trajectory_x.append(env.xy_p[0])  # 更新无人机路径的x坐标
        trajectory_y.append(env.xy_p[1])  # 更新无人机路径的y坐标
        trajectory_ex.append(env.xy_e[0])  # 更新无人机路径的x坐标
        trajectory_ey.append(env.xy_e[1])  # 更新无人机路径的y坐标

    # 绘制无人机路径
    axs[i].plot(trajectory_x, trajectory_y, color='red', linewidth=0.5)
    axs[i].plot(trajectory_ex, trajectory_ey, color='red', linewidth=0.5)

    # 打印每个episode的总奖励
    print(f'Episode {i+1} total reward:', total_reward)

# 显示子图窗口
plt.tight_layout()
plt.show()
# Out:
# Episode 1 total reward: -2228.366145387478
# Episode 2 total reward: -15890.641329808359
# Episode 3 total reward: -2229.6636728941294
# Episode 4 total reward: -1492.9721251277613
# Episode 5 total reward: -2093.8032492853395
# Episode 6 total reward: -2458.146285349635
# Episode 7 total reward: -1978.5470217908717
# Episode 8 total reward: -30121.990397988306
# Episode 9 total reward: -6656.864984120181
# Episode 10 total reward: -1985.2553524644263

# %%
import matplotlib.pyplot as plt

# 创建一个包含10个子图的窗口
fig, axs = plt.subplots(2, 5, figsize=(20, 8))
axs = axs.ravel()  # 将二维数组展平，方便通过索引访问每个子图

env = env_test1.DroneEnv()
for i in range(10):
    # 重置环境
    state, info = env.reset()
    trajectory_x = [env.xy_p[0]]  # 存储无人机路径的x坐标
    trajectory_y = [env.xy_p[1]]  # 存储无人机路径的y坐标
    trajectory_ex = [env.xy_e[0]]  # 存储无人机路径的x坐标
    trajectory_ey = [env.xy_e[1]]  # 存储无人机路径的y坐标
    
    # 在第i个子图中绘制环境和障碍物
    axs[i].scatter(env.xy_e[0], env.xy_e[1], marker='x', color='green', label='Goal')
    for k in env.obstacles:
        obstacle_circle = plt.Circle(k, env.r_obstacles, color='lightblue', fill=True)
        axs[i].add_patch(obstacle_circle)
    axs[i].set_xlim(env.space1.low[0], env.space1.high[0])
    axs[i].set_ylim(env.space1.low[1], env.space1.high[1])
    axs[i].set_xlabel('X')
    axs[i].set_ylabel('Y')
    axs[i].legend()
    axs[i].set_title(f'Episode {i+1}')

    # 通过预训练模型控制无人机执行任务并绘制路径
    model = PPO.load("best_model") 
    done = False
    total_reward = 0
    count = 0
    while not done:
        count += 1
        action, _states = model.predict(state, deterministic=True)
        next_state, reward, done, t, info = env.step(action)
        #if reward < -10:
            #print(state, action, reward)
        if count > 500:
            done = True
        total_reward += reward
        state = next_state
        trajectory_x.append(env.xy_p[0])  # 更新无人机路径的x坐标
        trajectory_y.append(env.xy_p[1])  # 更新无人机路径的y坐标
        trajectory_ex.append(env.xy_e[0])  # 更新无人机路径的x坐标
        trajectory_ey.append(env.xy_e[1])  # 更新无人机路径的y坐标

    # 绘制无人机路径
    axs[i].plot(trajectory_x, trajectory_y, color='red', linewidth=0.5)
    axs[i].plot(trajectory_ex, trajectory_ey, color='red', linewidth=0.5)

    # 打印每个episode的总奖励
    print(f'Episode {i+1} total reward:', total_reward)

# 显示子图窗口
plt.tight_layout()
plt.show()
# Out:
# Episode 1 total reward: -2692.5221841258704
# Episode 2 total reward: -32886.25393880427
# Episode 3 total reward: -43574.09229801929
# Episode 4 total reward: -1726.5355627210315
# Episode 5 total reward: -12982.40488757786
# Episode 6 total reward: -39820.41136305466
# Episode 7 total reward: -2646.1176318437706
# Episode 8 total reward: -37659.5436620749
# Episode 9 total reward: -2797.335165298555
# Episode 10 total reward: -21732.392310699273
